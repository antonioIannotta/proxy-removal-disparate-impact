# %%
from fair_by_design import compute
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
dataset = pd.read_excel('./default of credit card clients.xls')

# %%
dataset
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 0          1      20000    2          2         1   24      2      2     -1  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 0         -1  ...          0          0          0         0       689  \
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
dataset[dataset['EDUCATION'] == 1]
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 5          6      50000    1          1         2   37      0      0      0  \
# 6          7     500000    1          1         2   29      0      0      0
# 11        12     260000    2          1         2   51     -1     -1     -1
# 14        15     250000    1          1         2   29      0      0      0
# 16        17      20000    1          1         2   24      0      0      2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29986  29987     360000    1          1         2   35     -1     -1     -2
# 29987  29988     130000    1          1         2   34      0      0      0
# 29988  29989     250000    1          1         1   34      0      0      0
# 29989  29990     150000    1          1         2   35     -1     -1     -1
# 29993  29994     100000    1          1         2   38      0     -1     -1
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 5          0  ...      19394      19619      20024      2500      1815  \
# 6          0  ...     542653     483003     473944     55000     40000
# 11        -1  ...       8517      22287      13668     21818      9966
# 14         0  ...      59696      56875      55512      3000      3000
# 16         2  ...      18338      17905      19104      3200         0
# ...      ...  ...        ...        ...        ...       ...       ...
# 29986     -2  ...          0          0          0         0         0
# 29987      0  ...     108047      93708      97353      3000      2000
# 29988      0  ...     245750     175005     179687     65000      8800
# 29989     -1  ...        780          0          0      9054         0
# 29993      0  ...      70626      69473      55004      2000    111784
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 5           657      1000      1000       800                           0
# 6         38000     20239     13750     13770                           0
# 11         8583     22301         0      3640                           0
# 14         3000      3000      3000      3000                           0
# 16         1500         0      1650         0                           1
# ...         ...       ...       ...       ...                         ...
# 29986         0         0         0         0                           0
# 29987     93000      4000      5027      4005                           0
# 29988      9011      6000      7000      6009                           0
# 29989       783         0         0         0                           0
# 29993      4000      3000      2000      2000                           0
#
# [10585 rows x 25 columns]

# %%
protected_attributes = ['SEX', 'AGE']

# %%
compute(dataset, protected_attributes, 0.8)
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 29995    1
# 29996    2
# 29997    2
# 29998    1
# 29999    1
# Name: MARRIAGE, Length: 30000, dtype: int64
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 compute(dataset, protected_attributes, 0.8)
#
# File ~/Scrivania/proxy-removal-disparate-impact/fair_by_design.py:11, in compute(dataset, protected_attributes, confidence_threshold)
#       9 while DisparateImpact().fairness_evaluation(dataset, protected_attributes) == 'fair':
#      10     proxy_variables = return_proxy_variables(dataset, confidence_threshold)
# ---> 11     dataset = proxy_fixing(dataset, proxy_variables, protected_attributes)
#      13 return dataset
#
# File ~/Scrivania/proxy-removal-disparate-impact/proxy_ops.py:47, in proxy_fixing(original_dataset, proxy_variables, sensitive_attributes)
#      45 for antecedent in row['Antecedent']:
#      46     consequent = row['Consequent']
# ---> 47     disparate_impact_value = _compute_disparate_impact_for_proxy(antecedent, consequent,
#      48                                                                  original_dataset)
#      49     if not 0.8 <= disparate_impact_value <= 1.25:
#      50         original_dataset = _remove_proxy_from_dataset(original_dataset, row['Antecedent'])
#
# File ~/Scrivania/proxy-removal-disparate-impact/proxy_ops.py:65, in _compute_disparate_impact_for_proxy(antecedent, consequent, original_dataset)
#      60 protected_value = consequent.split(' = ')[1]
#      62 unprivileged_probability = _compute_disparate_impact(original_dataset, proxy, proxy_value, protected_column,
#      63                                                      protected_value, False)
# ---> 65 privileged_probability = _compute_disparate_impact(original_dataset, proxy, proxy_value, protected_column,
#      66                                                    protected_value, True)
#      68 return unprivileged_probability / privileged_probability
#
# File ~/Scrivania/proxy-removal-disparate-impact/proxy_ops.py:76, in _compute_disparate_impact(dataset, proxy, proxy_value, protected_column, protected_value, privileged_group)
#      74 if privileged_group is True:
#      75     proxy_columns_data = dataset[dataset[proxy] == proxy_value]
# ---> 76     result = len(proxy_columns_data[proxy_columns_data[protected_column] == protected_value]) / len(
#      77         proxy_columns_data)
#      78 else:
#      79     proxy_columns_data = dataset[dataset[proxy] != proxy_value]
#
# ZeroDivisionError: division by zero
