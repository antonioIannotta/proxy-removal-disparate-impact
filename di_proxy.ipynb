# %%
from fair_by_design import compute
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from dataset_preprocessing import *
from proxy_detection import return_proxy_variables
from proxy_ops import *

# %%
dataset = pd.read_excel('./default of credit card clients.xls')

# %%
dataset
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 0          1      20000    2          2         1   24      2      2     -1  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 0         -1  ...          0          0          0         0       689  \
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
protected_attributes = ['SEX', 'AGE']

# %%
dataset['EDUCATION']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 29995    3
# 29996    3
# 29997    2
# 29998    3
# 29999    2
# Name: EDUCATION, Length: 30000, dtype: int64

# %%
dataset['MARRIAGE']
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 29995    1
# 29996    2
# 29997    2
# 29998    1
# 29999    1
# Name: MARRIAGE, Length: 30000, dtype: int64

# %%
compute(dataset, protected_attributes, 0.8)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
#           ID  LIMIT_BAL  SEX  EDUCATION  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 0          1      20000    1          2    0      2      2     -1     -1  \
# 1          2     120000    1          2    0     -1      2      0      0
# 2          3      90000    1          2    0      0      0      0      0
# 3          4      50000    1          2    1      0      0      0      0
# 4          5      50000    0          2    1     -1      0     -1      0
# ...      ...        ...  ...        ...  ...    ...    ...    ...    ...
# 29995  29996     220000    0          3    1      0      0      0      0
# 29996  29997     150000    0          3    1     -1     -1     -1     -1
# 29997  29998      30000    0          2    1      4      3      2     -1
# 29998  29999      80000    0          3    1      1     -1      0      0
# 29999  30000      50000    0          2    1      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 0         -2  ...          0          0          0         0       689  \
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996      0  ...       8979       5190          0      1837      3526
# 29997      0  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 24 columns]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 compute(dataset, protected_attributes, 0.8)
#
# File ~/Scrivania/proxy-removal-disparate-impact/fair_by_design.py:10, in compute(dataset, protected_attributes, confidence_threshold)
#       8 dataset = fix_protected_attributes(dataset, protected_attributes)
#       9 while DisparateImpact().fairness_evaluation(dataset, protected_attributes) == 'fair':
# ---> 10     dataset = proxy_fixing(dataset, protected_attributes)
#      11     print(dataset)
#      13 return dataset
#
# File ~/Scrivania/proxy-removal-disparate-impact/proxy_ops.py:56, in proxy_fixing(original_dataset, sensitive_attributes)
#      53         else:
#      54             continue
# ---> 56 return dataset
#
# UnboundLocalError: local variable 'dataset' referenced before assignment

# %%
dataset['MARRIAGE']
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 29995    1
# 29996    2
# 29997    2
# 29998    1
# 29999    1
# Name: MARRIAGE, Length: 30000, dtype: int64
